# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDj4MiTZu1o7ityPlWJ8nXzUc-dj2Tx0vuADbU6_tb8GoVGWERU6ndYoRaiFhwUdy-_22x4dYgDCp8sG8ugvEf8G9SCv2hGXjgxO1kdXhKznYyBol3nvCn6Dln3ksLgw4TVtdinCNojlC6exUc5FXaWqZN26GM46zHuo4yN34gcZ5Ss_e6_NlMuJ0LBNuG0wnbxJFGkrYHZAe9QvEkax899eqyWQKSRS8l3WzUARkul7Nq04GJlRbp7BSacZNlqpNnZolAkC-21m2d3R9whYBqRv0Wta_-x4UCLfUHS7U-3jz-LSGX_cfUJrkPfThLPs4G9xAOipEZELuMrA70-vBC82J0l51MkdDM9B8ca_ChJcP_dr3YNY65A1BQbVGs0bqq6zUyg86kK3_W9eU_3HpVZh4v86qrChnGzvCZwgLW3iUSJzYuQXzmd',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %% [markdown]
# When we call the hotels variable to look at the JSON data, we get the following at the top of the output. Scroll through the information. Below the next_page_token is a results dictionary. To get all the hotels in the results dictionary we can get the length of this dictionary by using, len(hotels["results"]).

# %%
len(hotels["results"])
# Out:
# 20

# %% [markdown]
# The output of the len(hotels["results"]) returns 20 hotels. To retrieve more hotels, use the next_page_token, as it states in the Google Maps documentation. Upon closer examination of the JSON file, we see that the first hotel is Hôtel Duo, which is a value for the key name.
#
# How would you retrieve the name of the first hotel in the results dictionary?

# %%
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'
