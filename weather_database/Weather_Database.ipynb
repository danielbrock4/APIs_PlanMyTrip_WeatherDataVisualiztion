# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Use the citipy module to determine city based on latitude and longitude.
    # Under "Looking up with coordinates," the first line says from citipy import citipy, meaning we'll import the citipy script from the citipy module.
    # When a Python file containing a script is imported to use in another Python script, the .py extension does not need to be added to the name of the file when using the import statement.    
from citipy import citipy

# Import the datetime module from the datetime library.
    # If we want to convert the timestamp to the International Organization for Standardization (ISO) format, or YYYY-MM-DD-HH-MM-SS, we need to use the Python datetime module.
from datetime import datetime

# Import the API key.
    # When a Python file containing a script is imported to use in another Python script, the .py extension does not need to be added to the name of the file when using the import statement.
from config import weather_api_key


# Import the time module.
    #  import the time module to get the current date, rather than the datetime module that we used to convert the date.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the requests library.
    # To request JSON data over the internet, we use the Requests Library in Python. 
import requests

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data (25 points)
#
# ### 3. Create a new set of 2,000 random latitudes and longitudes.

# %%
# Create a set of random latitude and longitude combinations.
    # 1) Create arrays of latitudes and longitudes, we'll declare each array as a variable. 
    # 2) Use Numpty random uniform because its faster to generate the random latitudes and longtitudes.
            # To generate more than one floating-point decimal number between –90 and 90, we can add the size parameter when we use the NumPy module and set that equal to any whole number.
    # 3) Use zip() we'll pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.

lats = np.random.uniform(low=-90.00, high=90.000, size=1500)
lngs = np.random.uniform(-180.000, 180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)
coordinates[:3]
# Out:
# [(-12.484171919892049, 163.28541576741026),
#  (-68.1776280445993, 99.5724880289115),
#  (87.80119197887382, -108.29002564170132)]

# %% [markdown]
# ### 4. Get the nearest city using the citipy module.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %% [markdown]
# ### 5. Perform an API call with the OpenWeatherMap.

# %%
# Starting URL for Weather Map API Call.
# Structure example = api.openweathermap.org/data/2.5/weather?q={city name},{state code},{country code}&appid={API key}
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### 6. Retrieve the following information from the API call:
#
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description- (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create the for loop with the enumerate() method and reference the index and the city in the list.
    # Use the enumerate() method to get the index of the city for logging purposes and the city for creating an endpoint URL as an alternative 
    # way to iterate through the list of cities and retrieve both the index, and the city from the list.
for i, city in enumerate(cities):    
    
    # Group cities in sets of 50 for logging purposes.
        #In the conditional statement, we check if the remainder of the index divided by 50 is equal to 0 and if the index is greater than or equal to 50. 
        # If the statement is true, then the set_count and the record_count are incremented by 1.
    if (i % 50 == 0 and i >= 50):
        # % is modulo operation in python for example expression "5 mod 2" would evaluate to 1, because 5 divided by 2 has a quotient of 2 and a remainder of 1, while "9 mod 3" would evaluate to 0,
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
        # Inside the conditional statement, we create the URL endpoint for each city, as before. However, we are removing the blank spaces in the city name 
        # and concatenating the city name with, city.replace(" ","+"). This will find the corresponding weather data for the city instead of finding the weather data for the first part of the city name.
            # Compare the URLs for Cabo (Links to an external site.) and Cabo San Lucas
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
        # Add a print statement that tells us the record count and set count, and the city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON for the current city and retrieve data.
            # If there is no weather data for the city, i.e. , a <Response [404]> then there is no weather to retrieve and City not found. Skipping... is printed.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            # If there is weather data for the city, we will retrieve the latitude, longitude, maximum temperature, humidity, cloudiness, wind speed, and date and assign those values to variables.
            # We could write a try-except block for each one of these parameters to handle the KeyError if the data wasn't found, but since these parameters are always present in the response this won't be necessary.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            # We append the cities list with a dictionary for that city, where the key-value pairs are the values from our weather parameters.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    # Below the try block and after the except block, we add the closing print statement, which will let us know the data retrieval has been completed. 
    # Make sure that your except block is indented and in line with the try block, and that the print statements are flush with the margin.
    except:
        print("City not found. Skipping...")
        # Add the pass statement, which is a general purpose statement to handle all errors encountered and to allow the program to continue.
        # NOTE: Generally, it isn't good coding practice to add the pass statement to the except block. Ideally, we want to handle or catch each error as it happens and do something specific 
            # (e.g., add another try block or print out the error).
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kirakira
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | roald
# Processing Record 5 of Set 1 | derzhavinsk
# Processing Record 6 of Set 1 | shimoda
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | quepos
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | verkhoyansk
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | bac lieu
# Processing Record 14 of Set 1 | talnakh
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | chapais
# Processing Record 20 of Set 1 | beringovskiy
# Processing Record 21 of Set 1 | tynda
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | nishihara
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | storsteinnes
# Processing Record 26 of Set 1 | pemangkat
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | pedernales
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 1 | harper
# Processing Record 35 of Set 1 | rauma
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | shiyan
# Processing Record 40 of Set 1 | khandyga
# Processing Record 41 of Set 1 | herrenberg
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | pinheiro machado
# Processing Record 46 of Set 1 | misratah
# Processing Record 47 of Set 1 | ahipara
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | makakilo city
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | saint-francois
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | port hedland
# Processing Record 4 of Set 2 | ambilobe
# Processing Record 5 of Set 2 | brae
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | sao joao da barra
# Processing Record 9 of Set 2 | zwedru
# Processing Record 10 of Set 2 | lubango
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | shelburne
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | kalakamati
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | sao felix do xingu
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | dunedin
# Processing Record 21 of Set 2 | patur
# Processing Record 22 of Set 2 | kleinblittersdorf
# Processing Record 23 of Set 2 | binzhou
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | tual
# Processing Record 27 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | aripuana
# Processing Record 31 of Set 2 | bousso
# Processing Record 32 of Set 2 | aranos
# Processing Record 33 of Set 2 | gamba
# Processing Record 34 of Set 2 | lillooet
# Processing Record 35 of Set 2 | lasa
# Processing Record 36 of Set 2 | banning
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | lashio
# Processing Record 40 of Set 2 | ciudad bolivar
# Processing Record 41 of Set 2 | tignere
# Processing Record 42 of Set 2 | tukrah
# Processing Record 43 of Set 2 | lexington
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | dubbo
# Processing Record 46 of Set 2 | veere
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | hasaki
# Processing Record 1 of Set 3 | novorudnyy
# Processing Record 2 of Set 3 | anori
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | bilma
# Processing Record 5 of Set 3 | isangel
# Processing Record 6 of Set 3 | melbourne
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | keti bandar
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | fevik
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | nanakuli
# Processing Record 16 of Set 3 | acarau
# Processing Record 17 of Set 3 | ankazoabo
# Processing Record 18 of Set 3 | numazu
# Processing Record 19 of Set 3 | russell
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | te anau
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | alta floresta
# Processing Record 24 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 3 | kneza
# City not found. Skipping...
# Processing Record 26 of Set 3 | port hardy
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | tabou
# Processing Record 29 of Set 3 | sungaipenuh
# Processing Record 30 of Set 3 | mangan
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | axim
# Processing Record 33 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 34 of Set 3 | nara
# Processing Record 35 of Set 3 | eureka
# Processing Record 36 of Set 3 | kigoma
# Processing Record 37 of Set 3 | busselton
# Processing Record 38 of Set 3 | westport
# Processing Record 39 of Set 3 | buin
# Processing Record 40 of Set 3 | wanaka
# Processing Record 41 of Set 3 | jumla
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | daru
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | thinadhoo
# Processing Record 47 of Set 3 | lardos
# Processing Record 48 of Set 3 | hami
# Processing Record 49 of Set 3 | chicama
# Processing Record 50 of Set 3 | enshi
# Processing Record 1 of Set 4 | boguchany
# Processing Record 2 of Set 4 | ulaangom
# Processing Record 3 of Set 4 | mulege
# Processing Record 4 of Set 4 | manta
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | murygino
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | dukat
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | ternate
# Processing Record 16 of Set 4 | inta
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | traverse city
# Processing Record 19 of Set 4 | kharp
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 4 | constitucion
# Processing Record 23 of Set 4 | conceicao do mato dentro
# Processing Record 24 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | crixas
# Processing Record 27 of Set 4 | homer
# Processing Record 28 of Set 4 | leshukonskoye
# Processing Record 29 of Set 4 | sabha
# Processing Record 30 of Set 4 | odweyne
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | mahajanga
# Processing Record 34 of Set 4 | coquimbo
# Processing Record 35 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 4 | klyuchi
# Processing Record 37 of Set 4 | chake chake
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | evensk
# Processing Record 41 of Set 4 | urengoy
# Processing Record 42 of Set 4 | bubaque
# Processing Record 43 of Set 4 | greytown
# Processing Record 44 of Set 4 | marsh harbour
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | bezhetsk
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | omboue
# Processing Record 50 of Set 4 | karratha
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | brigantine
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | munchenbuchsee
# Processing Record 8 of Set 5 | innisfail
# Processing Record 9 of Set 5 | mwinilunga
# Processing Record 10 of Set 5 | turayf
# Processing Record 11 of Set 5 | male
# Processing Record 12 of Set 5 | altar
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | lucea
# Processing Record 15 of Set 5 | mahebourg
# Processing Record 16 of Set 5 | klooga
# Processing Record 17 of Set 5 | atambua
# Processing Record 18 of Set 5 | noyabrsk
# Processing Record 19 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 5 | marshall
# Processing Record 21 of Set 5 | timra
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 5 | ningan
# City not found. Skipping...
# Processing Record 26 of Set 5 | san patricio
# Processing Record 27 of Set 5 | aswan
# Processing Record 28 of Set 5 | zhaocheng
# City not found. Skipping...
# Processing Record 29 of Set 5 | flagstaff
# Processing Record 30 of Set 5 | morondava
# Processing Record 31 of Set 5 | provost
# Processing Record 32 of Set 5 | atagay
# Processing Record 33 of Set 5 | mar del plata
# Processing Record 34 of Set 5 | cedar city
# Processing Record 35 of Set 5 | chishtian mandi
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | pyapon
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | sumbe
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | chontalpa
# Processing Record 42 of Set 5 | bud
# Processing Record 43 of Set 5 | adrar
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 46 of Set 5 | chapeco
# Processing Record 47 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 5 | sherman
# Processing Record 50 of Set 5 | cabedelo
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | kindberg
# Processing Record 3 of Set 6 | akyab
# Processing Record 4 of Set 6 | komsomolskiy
# Processing Record 5 of Set 6 | victoria
# Processing Record 6 of Set 6 | concepcion del oro
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | wageningen
# Processing Record 9 of Set 6 | soto la marina
# Processing Record 10 of Set 6 | novyy urengoy
# Processing Record 11 of Set 6 | carora
# Processing Record 12 of Set 6 | wuwei
# Processing Record 13 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 6 | gencsapati
# Processing Record 15 of Set 6 | waddan
# Processing Record 16 of Set 6 | pingliang
# Processing Record 17 of Set 6 | hatillo
# Processing Record 18 of Set 6 | carutapera
# Processing Record 19 of Set 6 | nakamura
# Processing Record 20 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 6 | tandil
# Processing Record 22 of Set 6 | la union
# Processing Record 23 of Set 6 | mayumba
# Processing Record 24 of Set 6 | pokhara
# Processing Record 25 of Set 6 | kampot
# Processing Record 26 of Set 6 | quixere
# Processing Record 27 of Set 6 | bell ville
# Processing Record 28 of Set 6 | egvekinot
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | sao pedro do sul
# Processing Record 31 of Set 6 | sobolevo
# Processing Record 32 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 6 | nabire
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | vilyuysk
# Processing Record 36 of Set 6 | viedma
# Processing Record 37 of Set 6 | micheweni
# Processing Record 38 of Set 6 | rio gallegos
# Processing Record 39 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 6 | pingxiang
# Processing Record 42 of Set 6 | tasiilaq
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | nyagan
# Processing Record 45 of Set 6 | provideniya
# Processing Record 46 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 47 of Set 6 | okakarara
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | abong mbang
# Processing Record 50 of Set 6 | sain alto
# Processing Record 1 of Set 7 | chegdomyn
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 7 | zhanaozen
# Processing Record 5 of Set 7 | sao jose da coroa grande
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | olafsvik
# Processing Record 8 of Set 7 | marzuq
# Processing Record 9 of Set 7 | norman wells
# Processing Record 10 of Set 7 | cidreira
# Processing Record 11 of Set 7 | muravlenko
# Processing Record 12 of Set 7 | kapuskasing
# Processing Record 13 of Set 7 | neuquen
# Processing Record 14 of Set 7 | blackfoot
# Processing Record 15 of Set 7 | amalapuram
# Processing Record 16 of Set 7 | praya
# Processing Record 17 of Set 7 | rio cuarto
# Processing Record 18 of Set 7 | puerto penasco
# Processing Record 19 of Set 7 | santarem
# Processing Record 20 of Set 7 | kaiserslautern
# Processing Record 21 of Set 7 | chokurdakh
# Processing Record 22 of Set 7 | unity
# Processing Record 23 of Set 7 | ardakan
# Processing Record 24 of Set 7 | oktyabrskoye
# Processing Record 25 of Set 7 | kalat
# Processing Record 26 of Set 7 | gavle
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | bahua
# Processing Record 29 of Set 7 | bull savanna
# Processing Record 30 of Set 7 | bilibino
# Processing Record 31 of Set 7 | letnyaya stavka
# Processing Record 32 of Set 7 | jieshi
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | maridi
# Processing Record 35 of Set 7 | nouakchott
# Processing Record 36 of Set 7 | a
# City not found. Skipping...
# Processing Record 37 of Set 7 | kefamenanu
# Processing Record 38 of Set 7 | tura
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | savonlinna
# Processing Record 41 of Set 7 | bairiki
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | bontang
# Processing Record 44 of Set 7 | tingo maria
# Processing Record 45 of Set 7 | north bend
# Processing Record 46 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 7 | kazuno
# Processing Record 48 of Set 7 | san quintin
# Processing Record 49 of Set 7 | ambon
# Processing Record 50 of Set 7 | poso
# Processing Record 1 of Set 8 | dzhebariki-khaya
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | ngunguru
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | belmonte
# Processing Record 7 of Set 8 | jhargram
# Processing Record 8 of Set 8 | moreira sales
# Processing Record 9 of Set 8 | blagoyevo
# Processing Record 10 of Set 8 | hastings
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | waipawa
# Processing Record 13 of Set 8 | andra
# Processing Record 14 of Set 8 | swan hill
# Processing Record 15 of Set 8 | trincomalee
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | celestun
# Processing Record 18 of Set 8 | cravo norte
# Processing Record 19 of Set 8 | tomohon
# Processing Record 20 of Set 8 | kloulklubed
# Processing Record 21 of Set 8 | srednekolymsk
# Processing Record 22 of Set 8 | tezu
# Processing Record 23 of Set 8 | chapleau
# Processing Record 24 of Set 8 | sola
# Processing Record 25 of Set 8 | usinsk
# Processing Record 26 of Set 8 | ahtopol
# Processing Record 27 of Set 8 | nizhniy odes
# Processing Record 28 of Set 8 | avera
# Processing Record 29 of Set 8 | vallenar
# Processing Record 30 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 8 | kamenka
# Processing Record 32 of Set 8 | roros
# Processing Record 33 of Set 8 | bambous virieux
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | salym
# Processing Record 36 of Set 8 | semme
# Processing Record 37 of Set 8 | codrington
# Processing Record 38 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 8 | upington
# Processing Record 40 of Set 8 | muyezerskiy
# Processing Record 41 of Set 8 | phan thiet
# Processing Record 42 of Set 8 | vlist
# Processing Record 43 of Set 8 | port blair
# Processing Record 44 of Set 8 | tazovskiy
# Processing Record 45 of Set 8 | wellington
# Processing Record 46 of Set 8 | falmouth
# Processing Record 47 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 8 | lalsot
# Processing Record 49 of Set 8 | mildura
# Processing Record 50 of Set 8 | zlitan
# Processing Record 1 of Set 9 | the valley
# Processing Record 2 of Set 9 | vardo
# Processing Record 3 of Set 9 | januaria
# Processing Record 4 of Set 9 | gallup
# Processing Record 5 of Set 9 | oussouye
# Processing Record 6 of Set 9 | kavaratti
# Processing Record 7 of Set 9 | kuznechnoye
# Processing Record 8 of Set 9 | deputatskiy
# Processing Record 9 of Set 9 | saint-augustin
# Processing Record 10 of Set 9 | aksarka
# Processing Record 11 of Set 9 | sambava
# Processing Record 12 of Set 9 | saldanha
# Processing Record 13 of Set 9 | saint anthony
# Processing Record 14 of Set 9 | floro
# Processing Record 15 of Set 9 | sorland
# Processing Record 16 of Set 9 | huilong
# Processing Record 17 of Set 9 | byron bay
# Processing Record 18 of Set 9 | ranong
# Processing Record 19 of Set 9 | khash
# Processing Record 20 of Set 9 | namtsy
# Processing Record 21 of Set 9 | dingle
# Processing Record 22 of Set 9 | morant bay
# Processing Record 23 of Set 9 | rey bouba
# Processing Record 24 of Set 9 | teguldet
# Processing Record 25 of Set 9 | verkhnyaya tishanka
# Processing Record 26 of Set 9 | marawi
# Processing Record 27 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 28 of Set 9 | kushima
# Processing Record 29 of Set 9 | sungairaya
# Processing Record 30 of Set 9 | pirawa
# Processing Record 31 of Set 9 | asau
# Processing Record 32 of Set 9 | berlevag
# Processing Record 33 of Set 9 | nelson bay
# Processing Record 34 of Set 9 | vila velha
# Processing Record 35 of Set 9 | jingdezhen
# Processing Record 36 of Set 9 | merauke
# Processing Record 37 of Set 9 | san jose
# Processing Record 38 of Set 9 | murici
# Processing Record 39 of Set 9 | matagami
# Processing Record 40 of Set 9 | huarmey
# Processing Record 41 of Set 9 | yuzhno-kurilsk
# Processing Record 42 of Set 9 | aklavik
# Processing Record 43 of Set 9 | north myrtle beach
# Processing Record 44 of Set 9 | la orilla
# Processing Record 45 of Set 9 | lago da pedra
# Processing Record 46 of Set 9 | santa barbara
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | kodinsk
# Processing Record 49 of Set 9 | sarana
# Processing Record 50 of Set 9 | tessalit
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | lang son
# Processing Record 3 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 10 | hithadhoo
# Processing Record 5 of Set 10 | umkomaas
# Processing Record 6 of Set 10 | dogondoutchi
# Processing Record 7 of Set 10 | harare
# Processing Record 8 of Set 10 | namibe
# Processing Record 9 of Set 10 | ambunti
# Processing Record 10 of Set 10 | oranjemund
# Processing Record 11 of Set 10 | rundu
# Processing Record 12 of Set 10 | ivanovka
# Processing Record 13 of Set 10 | xocali
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | ayan
# Processing Record 16 of Set 10 | tabuk
# Processing Record 17 of Set 10 | pandan
# Processing Record 18 of Set 10 | christchurch
# Processing Record 19 of Set 10 | pirogovskiy
# Processing Record 20 of Set 10 | moulmeingyun
# City not found. Skipping...
# Processing Record 21 of Set 10 | la palma
# Processing Record 22 of Set 10 | springfield
# Processing Record 23 of Set 10 | tigil
# Processing Record 24 of Set 10 | ossora
# Processing Record 25 of Set 10 | biak
# Processing Record 26 of Set 10 | alhaurin el grande
# Processing Record 27 of Set 10 | luanda
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | grand-lahou
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | guerrero negro
# Processing Record 32 of Set 10 | freetown
# Processing Record 33 of Set 10 | barabinsk
# Processing Record 34 of Set 10 | yulara
# Processing Record 35 of Set 10 | edmonton
# Processing Record 36 of Set 10 | yamada
# Processing Record 37 of Set 10 | cabo san lucas
# Processing Record 38 of Set 10 | orhei
# Processing Record 39 of Set 10 | didwana
# Processing Record 40 of Set 10 | esmeraldas
# Processing Record 41 of Set 10 | todos santos
# Processing Record 42 of Set 10 | umaria
# Processing Record 43 of Set 10 | gafanha da encarnacao
# Processing Record 44 of Set 10 | dharchula
# Processing Record 45 of Set 10 | kutum
# Processing Record 46 of Set 10 | abu samrah
# Processing Record 47 of Set 10 | vostok
# Processing Record 48 of Set 10 | sulangan
# Processing Record 49 of Set 10 | esmeralda
# Processing Record 50 of Set 10 | mabaruma
# Processing Record 1 of Set 11 | sapa
# Processing Record 2 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 11 | chubbuck
# Processing Record 4 of Set 11 | rimbey
# Processing Record 5 of Set 11 | sinnamary
# Processing Record 6 of Set 11 | bullhead city
# Processing Record 7 of Set 11 | taywarah
# Processing Record 8 of Set 11 | shagonar
# Processing Record 9 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 11 | teya
# Processing Record 11 of Set 11 | sao geraldo do araguaia
# Processing Record 12 of Set 11 | sechura
# Processing Record 13 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 11 | moerai
# Processing Record 15 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 11 | dzaoudzi
# Processing Record 17 of Set 11 | san bartolome de tirajana
# Processing Record 18 of Set 11 | kosonsoy
# Processing Record 19 of Set 11 | los llanos de aridane
# Processing Record 20 of Set 11 | ketchikan
# Processing Record 21 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 11 | savannakhet
# Processing Record 23 of Set 11 | batang berjuntai
# Processing Record 24 of Set 11 | nyrob
# Processing Record 25 of Set 11 | alofi
# Processing Record 26 of Set 11 | ilulissat
# Processing Record 27 of Set 11 | aksu
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 11 | el sauzal
# Processing Record 31 of Set 11 | pangody
# Processing Record 32 of Set 11 | zheleznodorozhnyy
# Processing Record 33 of Set 11 | zaraza
# Processing Record 34 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 11 | owensboro
# Processing Record 36 of Set 11 | port moresby
# Processing Record 37 of Set 11 | iskateley
# Processing Record 38 of Set 11 | asosa
# Processing Record 39 of Set 11 | kapit
# Processing Record 40 of Set 11 | alekseyevka
# Processing Record 41 of Set 11 | sawakin
# Processing Record 42 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 11 | amot
# Processing Record 44 of Set 11 | deer lake
# Processing Record 45 of Set 11 | bonthe
# Processing Record 46 of Set 11 | cooma
# Processing Record 47 of Set 11 | gat
# Processing Record 48 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 50 of Set 11 | hovd
# Processing Record 1 of Set 12 | gizo
# Processing Record 2 of Set 12 | batagay
# Processing Record 3 of Set 12 | kachug
# Processing Record 4 of Set 12 | beloha
# Processing Record 5 of Set 12 | clyde river
# Processing Record 6 of Set 12 | torbay
# Processing Record 7 of Set 12 | milkovo
# Processing Record 8 of Set 12 | esso
# Processing Record 9 of Set 12 | okitipupa
# Processing Record 10 of Set 12 | karimganj
# Processing Record 11 of Set 12 | marmande
# Processing Record 12 of Set 12 | arima
# Processing Record 13 of Set 12 | lerwick
# Processing Record 14 of Set 12 | horka nad moravou
# Processing Record 15 of Set 12 | catamarca
# Processing Record 16 of Set 12 | hobyo
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | svetlogorsk
# Processing Record 19 of Set 12 | bonga
# Processing Record 20 of Set 12 | nouadhibou
# Processing Record 21 of Set 12 | ayna
# Processing Record 22 of Set 12 | kismayo
# Processing Record 23 of Set 12 | balabac
# Processing Record 24 of Set 12 | tinca
# Processing Record 25 of Set 12 | lorvao
# Processing Record 26 of Set 12 | mitsamiouli
# Processing Record 27 of Set 12 | cleveland
# Processing Record 28 of Set 12 | nemuro
# Processing Record 29 of Set 12 | sembakung
# Processing Record 30 of Set 12 | piripiri
# Processing Record 31 of Set 12 | shingu
# Processing Record 32 of Set 12 | progreso
# Processing Record 33 of Set 12 | coos bay
# Processing Record 34 of Set 12 | banjar
# Processing Record 35 of Set 12 | sao miguel do araguaia
# Processing Record 36 of Set 12 | gwadar
# Processing Record 37 of Set 12 | malpe
# Processing Record 38 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 12 | rucar
# Processing Record 40 of Set 12 | namatanai
# Processing Record 41 of Set 12 | ahuimanu
# Processing Record 42 of Set 12 | takoradi
# Processing Record 43 of Set 12 | espita
# Processing Record 44 of Set 12 | quelimane
# Processing Record 45 of Set 12 | skelleftea
# Processing Record 46 of Set 12 | kendari
# Processing Record 47 of Set 12 | road town
# Processing Record 48 of Set 12 | whitecourt
# Processing Record 49 of Set 12 | port-gentil
# Processing Record 50 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | mineiros
# Processing Record 2 of Set 13 | noumea
# Processing Record 3 of Set 13 | lazaro cardenas
# Processing Record 4 of Set 13 | taltal
# Processing Record 5 of Set 13 | verkh-usugli
# Processing Record 6 of Set 13 | masterton
# Processing Record 7 of Set 13 | pilar
# Processing Record 8 of Set 13 | rocha
# Processing Record 9 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 10 of Set 13 | karatau
# Processing Record 11 of Set 13 | tokzar
# City not found. Skipping...
# Processing Record 12 of Set 13 | maimon
# City not found. Skipping...
# Processing Record 13 of Set 13 | oum hadjer
# Processing Record 14 of Set 13 | paamiut
# Processing Record 15 of Set 13 | barda
# Processing Record 16 of Set 13 | lagoa
# Processing Record 17 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 18 of Set 13 | san vicente
# Processing Record 19 of Set 13 | caraubas
# Processing Record 20 of Set 13 | ostrovnoy
# Processing Record 21 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 13 | yabelo
# Processing Record 23 of Set 13 | hualmay
# Processing Record 24 of Set 13 | mangawan
# Processing Record 25 of Set 13 | pula
# Processing Record 26 of Set 13 | williams lake
# Processing Record 27 of Set 13 | marsa matruh
# Processing Record 28 of Set 13 | zhigansk
# Processing Record 29 of Set 13 | kerema
# Processing Record 30 of Set 13 | nong han
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 573

# %% [markdown]
# ### 7. Add the data to a new DataFrame.
#
# Before exporting your new DataFrame as a CSV file, take a moment to confirm that it looks similar to the image below:

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kirakira -10.4544  161.9205     83.26        78         100
# 1        Albany  42.6001  -73.9662     58.08        88         100
# 2   Yellowknife  62.4560 -114.3525    -16.58        83          75
# 3         Roald  62.5833    6.1333     37.09        59          75
# 4   Derzhavinsk  51.1000   66.3167     20.82        97         100
# 5       Shimoda  34.6667  138.9500     56.10        82          80
# 6       Rikitea -23.1203 -134.9692     76.42        72          73
# 7        Quepos   9.4236  -84.1652     87.10        86          77
# 8  Saint George  37.1041 -113.5841     68.47        24           1
# 9   Verkhoyansk  67.5447  133.3850    -41.10        92          78
#
#    Wind Speed Country                 Date      Description
# 0        7.40      SB  2021-12-06 22:34:24  overcast clouds
# 1       11.54      US  2021-12-06 22:30:48       light rain
# 2        4.61      CA  2021-12-06 22:31:14    broken clouds
# 3       20.71      NO  2021-12-06 22:38:43    broken clouds
# 4        5.28      KZ  2021-12-06 22:38:44       light snow
# 5       18.19      JP  2021-12-06 22:38:44    broken clouds
# 6        8.50      PF  2021-12-06 22:32:14    broken clouds
# 7        2.37      CR  2021-12-06 22:38:44    broken clouds
# 8        0.00      US  2021-12-06 22:32:12        clear sky
# 9        3.87      RU  2021-12-06 22:38:45    broken clouds

# %% [markdown]
# ### 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
